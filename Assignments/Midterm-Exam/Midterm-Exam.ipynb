# %% [markdown]
# # STAT 7220 - Midterm Exam
# ## Dr. Austin R. Brown
# ### School of Data Science & Analytics
# ### Kennesaw State University
#
# **DUE: October 24, 2025**
#
# **PART 1**
# Question 1. Briefly define the objective of this experiment
#
# We're measuring how comfortable each grip felt, using a rating from 1 to 10 (higher numbers mean more comfort).
#
# **Question 2.** Specify the outcome variable
#
# We're measuring how comfortable each grip felt, using a rating from 1 to 10 (higher numbers mean more comfort).
#
# **Question 3.** Specify the independent variable. What are some possible lurking variables?
#
# We changed the grip material (plastic, rubber, silicone, metal).
# Other things that might affect comfort (even though we didn’t control for them) include:
# Size of the gamer’s hands
# How long they play
# Personal preferences
# Prior hand/wrist injuries
# Room temperature while gaming
#
# **Question 4.** Briefly explain why a completely randomized design may be appropriate for this experiment.
#
# Since all the gamers play the same game and are professionals, randomizing who gets which grip is fair and helps make the results more reliable.
#
# **Question 5.** State the null and alternative hypotheses for this experiment.
#
# Null hypothesis (H₀): All grip materials are equally comfortable.
# Alternative hypothesis (H₁): At least one grip material feels more or less comfortable than the others.
#
#
# **Question 9.** Report the F-statistic and its associated p-value for the test for the treatment factor. Which of our two hypotheses is more strongly supported? Why?
#
# **Question 10.** If the data more strongly support the alternative hypothesis, perform Tukey's HSD post-hoc test to determine which material types are significantly different from each other. If the data more strongly support the null hypothesis, explain why a post-hoc test would not be appropriate.
#
# **Question 11.** Write a brief, contextual conclusion summarizing the results of your analyses.
#
# **PART 2 INSTRUCTIONS:** The same video game controller manufacturing company is now trying to get into the business of creating virtual reality/artificial intelligence content for education. Specifically, they want to build a VR experience to simulate working with elderly patients at a healthcare facility to better prepare nursing students for potential careers in working with elderly patients. To test the VR's effectiveness, a group of 40 undergraduate nursing students were randomly and equally assigned to either a class session utilizing the VR or a class session using a traditional technique for teaching strategies for working with elderly patients. At the end of the class session, a 50 question quiz was given to both groups which measures attitudes toward elderly people. Scores range from 0-50 with greater scores indicating more favorable attitudes toward elderly people and vice versa. However, some students in the group have had prior working experience with elderly people which may have an effect on the quiz outcome. So in the experiment, we document which students have had prior working experience with elderly people and which haven't. The results of the experiment are contained in the `Nursing VR Study.xlsx` file. With these data, your tasks are:
#
# **Question 1.** Briefly define the objective of this experiment
#
# **Question 2.** Specify the outcome variable
#
# **Question 3.** Specify the independent variable and blocking factor. What are some possible lurking variables?
#
# **Question 4.** Briefly explain why a randomized block design would be appropriate here. Similarly, explain why a completely randomized design would not be appropriate.
#
# **Question 5.** State the null and alternative hypotheses for this experiment.
#
# **Question 10.** If the data more strongly support the alternative hypothesis, perform Tukey's HSD post-hoc test to determine which levels of the treatment effect are significantly different from each other. If the data more strongly support the null hypothesis, explain why a post-hoc test would not be appropriate.
#
# **Question 11.** Write a brief, contextual conclusion summarizing the results of your analyses, including potential limitations of this experiment.
#
# **PART 3 INSTRUCTIONS:** Please briefly respond to the following questions:
#
# **Question 1.** Give a reason why one-factor CRD wouldn't generally be appropriate for studies involving human participants.
#
# **Question 2.** What is the purpose of post-hoc tests?
#
# **Question 3.** Explain the difference between RBD and LSD.
#
# **Question 4.** Explain why randomization is important in designing experiments.
#
# **Question 5.** Explain why replication is important in designing experiments.

# %%
# === COURSE REPO SETUP === #

# 1. ENTER your GitHub username (the one that owns your fork)
github_username = "christinatalerico13"

# 2. Name of the repo (don't change unless your fork name is different)
repo_name = "STAT-7220-Applied-Experimental-Design"

# 3. Build the full repo URL for cloning
repo_url = f"https://github.com/{github_username}/{repo_name}.git"

import os

# --- Detect if we're already in a repo ---
cwd = os.getcwd()
if cwd.endswith(repo_name):
    print(f"✅ Already inside repo folder: {cwd}")
else:
    # --- If the repo folder exists, check if it's nested ---
    if os.path.exists(repo_name):
        print(f"⚠️ Found existing folder '{repo_name}'. Skipping clone to avoid nesting.")
    else:
        print(f"📥 Cloning repo from {repo_url}...")
        os.system(f"git clone {repo_url}")

    # --- Change to repo directory ---
    if os.path.exists(repo_name):
        os.chdir(repo_name)
        print(f"📂 Changed directory to: {os.getcwd()}")
    else:
        print("❌ ERROR: Repo folder not found. Please check your GitHub username.")

# --- Check if this is the instructor's repo instead of student's fork ---
# This command needs to be run from within the repository directory
remote_url = os.popen("git config --get remote.origin.url").read().strip()

if "abrown9008" in remote_url:
    print("⚠️ WARNING: You are working in the instructor's repo, not your fork!")
else:
    print(f"🔗 Connected to fork at: {remote_url}")

print("💡 Please fork the repo to your own account and update 'github_username' above.")


# Set Today's Directory #

today_dir = "Assignments"
os.chdir(today_dir)
print(f"📂 Changed directory to: {os.getcwd()}")
# Out:
# 📥 Cloning repo from https://github.com/christinatalerico13/STAT-7220-Applied-Experimental-Design.git...
# 📂 Changed directory to: /content/STAT-7220-Applied-Experimental-Design
# 🔗 Connected to fork at: https://github.com/christinatalerico13/STAT-7220-Applied-Experimental-Design.git
# 💡 Please fork the repo to your own account and update 'github_username' above.
# 📂 Changed directory to: /content/STAT-7220-Applied-Experimental-Design/Assignments

# %% [markdown]
# Question 6. Perform appropriate exploratory analysis, including summary statistics and data visualizations. Do the results of these analyses support the null or alternative hypothesis more strongly?
#
# These numbers show that Silicone has the highest average comfort rating, while Metal has the lowest. The spread (standard deviation) is also larger for Rubber, suggesting more variability in how users felt about it.
# I also created a boxplot with individual data points to visually compare the comfort scores across materials. The plot showed:
# Clear separation between group averages.
# Minimal overlap in the interquartile ranges (especially between Silicone and other materials).
# Outliers were not a major concern.
# ✅ Interpretation:
# The differences in means, combined with the visual spread of data, suggest that comfort ratings differ between materials. This supports the alternative hypothesis: at least one material provides a significantly different comfort level than the others.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# Load the data
file_path = "/content/STAT-7220-Applied-Experimental-Design/Assignments/Midterm-Exam/Video Game Controllers.xlsx"
video_game_df = pd.read_excel(file_path)

# -----------------------------
# Q6: Summary statistics & visualization
# -----------------------------
summary_stats = video_game_df.groupby('Material')['Comfort'].describe()
print("\nSummary Statistics by Material:")
print(summary_stats)

# Boxplot with individual data points
plt.figure(figsize=(8, 6))
sns.boxplot(data=video_game_df, x='Material', y='Comfort')
sns.stripplot(data=video_game_df, x='Material', y='Comfort', color='black', alpha=0.6, jitter=True)
plt.title('Comfort Ratings by Grip Material')
plt.ylabel('Comfort (1-10)')
plt.xlabel('Material')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Summary Statistics by Material:
#           count  mean       std  min    25%   50%    75%  max
# Material
# Metal      10.0  4.95  0.538000  4.2  4.450  5.05  5.375  5.6
# Plastic    10.0  5.89  0.448330  5.2  5.625  5.80  6.125  6.8
# Rubber     10.0  6.57  0.860297  5.3  6.050  6.35  6.975  8.0
# Silicone   10.0  8.32  0.689283  7.3  7.800  8.50  8.875  9.2

# %% [markdown]
# Question 7. Build a two-way ANOVA model. Test the assumption of normality using both a visual method and a testing method. Do the results of the normality test(s) support the assumption of normality?
#
# The normality of residuals was tested using both a Q-Q plot and the Shapiro-Wilk test. The Q-Q plot shows that the residuals closely follow the red reference line, indicating that they are approximately normally distributed. The Shapiro-Wilk test produced a p-value of 0.951, which is greater than 0.05, so we fail to reject the null hypothesis of normality. Therefore, both the visual and statistical methods suggest that the assumption of normality is met for this ANOVA model.

# %%
# -----------------------------
# Q7: One-way ANOVA + Normality test
# -----------------------------
# Fit the ANOVA model
model = ols('Comfort ~ C(Material)', data=video_game_df).fit()

# Residual normality test (Shapiro-Wilk)
shapiro_test = stats.shapiro(model.resid)
print("Shapiro-Wilk Test:", shapiro_test)

# Q-Q Plot
sm.qqplot(model.resid, line='s')
plt.title("Q-Q Plot of Residuals")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Shapiro-Wilk Test: ShapiroResult(statistic=np.float64(0.9884713563029021), pvalue=np.float64(0.9509274348395812))

# %% [markdown]
# Question 8. Test the assumption of homogeneity of variance using both a testing and visual method. Do the results of the test(s) support the assumption of homogeneity of variance?
#
# Levene’s test was used to check the assumption of equal variances among the four material groups. The test produced a statistic of 1.3685 with a p-value of 0.2679. Since the p-value is greater than 0.05, we fail to reject the null hypothesis that the group variances are equal. In addition, the residuals versus fitted values plot showed no clear pattern or funnel shape, further supporting this result. Therefore, the assumption of homogeneity of variance is satisfied for this ANOVA model.

# %%
# -----------------------------
# Q8: Homogeneity of variances test
# -----------------------------
# Levene’s test
levene_test = stats.levene(
    *[group["Comfort"].values for name, group in video_game_df.groupby("Material")]
)
print("\nLevene’s Test for Equal Variance:")
print(f"Statistic = {levene_test.statistic:.4f}, p-value = {levene_test.pvalue:.4f}")

# Residuals vs Fitted Plot
plt.figure(figsize=(8, 6))
sns.scatterplot(x=model.fittedvalues, y=model.resid)
plt.axhline(0, linestyle='--', color='gray')
plt.title("Residuals vs Fitted Values")
plt.xlabel("Fitted Values")
plt.ylabel("Residuals")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Levene’s Test for Equal Variance:
# Statistic = 1.3685, p-value = 0.2679

# %% [markdown]
# Question 9. Report the F-statistic and its associated p-value for the test for the treatment factor. Which of our two hypotheses is more strongly supported? Why?
#
# The ANOVA test produced an F-statistic of 47.48 with a corresponding p-value of 1.35 × 10⁻¹². Since the p-value is far below the common significance level of 0.05, we reject the null hypothesis that all group means are equal. This result provides strong statistical evidence that the type of grip material has a significant effect on the comfort rating. Therefore, the data more strongly support the alternative hypothesis: at least one material differs in mean comfort level from the others.

# %%
# -----------------------------
# Q9: ANOVA Table
# -----------------------------
anova_table = sm.stats.anova_lm(model, typ=2)
print("\nANOVA Table:")
print(anova_table)
# Out:
# ANOVA Table:
#                sum_sq    df          F        PR(>F)
# C(Material)  60.73675   3.0  47.478405  1.348029e-12
# Residual     15.35100  36.0        NaN           NaN

# %% [markdown]
# **Question 10.** If the data more strongly support the alternative hypothesis, perform Tukey's HSD post-hoc test to determine which levels of the treatment effect are significantly different from each other. If the data more strongly support the null hypothesis, explain why a post-hoc test would not be appropriate.
#
#
# Tukey’s HSD post-hoc test was conducted following a significant ANOVA result to determine which grip materials differed in average comfort ratings. The test showed that Silicone was significantly more comfortable than Metal, Plastic, and Rubber. Metal was significantly less comfortable than all other materials. However, there was no significant difference between Plastic and Rubber (p = 0.1104). These results suggest that while some materials (like Silicone and Metal) stand out in terms of comfort, others (Plastic and Rubber) are perceived similarly by users.

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# Run Tukey's HSD test
tukey_result = pairwise_tukeyhsd(
    endog=video_game_df['Comfort'],
    groups=video_game_df['Material'],
    alpha=0.05
)

# Print the results
print(tukey_result.summary())
# Out:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#  group1  group2  meandiff p-adj   lower  upper  reject
# ------------------------------------------------------
#   Metal  Plastic     0.94 0.0139  0.1535 1.7265   True
#   Metal   Rubber     1.62    0.0  0.8335 2.4065   True
#   Metal Silicone     3.37    0.0  2.5835 4.1565   True
# Plastic   Rubber     0.68 0.1104 -0.1065 1.4665  False
# Plastic Silicone     2.43    0.0  1.6435 3.2165   True
#  Rubber Silicone     1.75    0.0  0.9635 2.5365   True
# ------------------------------------------------------

# %% [markdown]
# Question 11. Write a brief, contextual conclusion summarizing the results of your analyses.
#
# This experiment evaluated whether the material used for video game controller grips affects user comfort, based on ratings from professional gamers. A one-way ANOVA revealed a statistically significant difference in comfort ratings between the four grip materials. The analysis met all assumptions, including normality and equal variances. Post-hoc testing using Tukey’s HSD showed that Silicone grips were rated significantly more comfortable than all other materials, while Metal grips were rated significantly less comfortable. No significant difference was found between Plastic and Rubber grips. These findings suggest that material choice plays a meaningful role in perceived comfort, with Silicone emerging as the best option for maximizing user satisfaction.
