# %%
# === COURSE REPO SETUP === #

# 1. ENTER your GitHub username (the one that owns your fork)
github_username = "christinatalerico13"

# 2. Name of the repo (don't change unless your fork name is different)
repo_name = "STAT-7220-Applied-Experimental-Design"

# 3. Build the full repo URL for cloning
repo_url = f"https://github.com/{github_username}/{repo_name}.git"

import os

# --- Detect if we're already in a repo ---
cwd = os.getcwd()
if cwd.endswith(repo_name):
    print(f"✅ Already inside repo folder: {cwd}")
else:
    # --- If the repo folder exists, check if it's nested ---
    if os.path.exists(repo_name):
        print(f"⚠️ Found existing folder '{repo_name}'. Skipping clone to avoid nesting.")
    else:
        print(f"📥 Cloning repo from {repo_url}...")
        os.system(f"git clone {repo_url}")

    # --- Change to repo directory ---
    if os.path.exists(repo_name):
        os.chdir(repo_name)
        print(f"📂 Changed directory to: {os.getcwd()}")
    else:
        print("❌ ERROR: Repo folder not found. Please check your GitHub username.")

# --- Check if this is the instructor's repo instead of student's fork ---
# This command needs to be run from within the repository directory
remote_url = os.popen("git config --get remote.origin.url").read().strip()

if "abrown9008" in remote_url:
   print("⚠️ WARNING: You are working in the instructor's repo, not your fork!")
   print("💡 Please fork the repo to your own account and update `github_username` above.")
else:
    print(f"🔗 Connected to fork at: {remote_url}")

# Set Today's Directory #
# today_dir =
# os.chdir(today_dir)
# print(f"📂 Changed directory to: {os.getcwd()}")
# Out:
# 📥 Cloning repo from https://github.com/christinatalerico13/STAT-7220-Applied-Experimental-Design.git...
# 📂 Changed directory to: /content/STAT-7220-Applied-Experimental-Design
# 🔗 Connected to fork at: https://github.com/christinatalerico13/STAT-7220-Applied-Experimental-Design.git

# %% [markdown]
# # Homework 2: Randomized Block and Latin Square Designs
# ## Dr. Austin R. Brown
# ### School of Data Science & Analytics
# ### Kennesaw State University
#
# **DUE: October 3, 2025**
#
# **PART 1 INSTRUCTIONS:** You are an educational researcher interested in comparing different methods for teaching data science to undergraduate students. There are three different methods you are interested in comparing: (1) Direct Instruction (traditional method); (2) Inquiry-Based Learning (teacher facilitates student problem solving); (3) Collaborative Learning (students working in small groups). To compare these methods, you decide to randomly recruit undergraduate data science students to be part of a workshop on hypothesis testing basics. Students will be randomly assigned to one of three workshops, where each workshop employs a different teaching method. At the end of the workshop, students will be given a 50-question quiz where their understanding of hypothesis testing will be assessed. Percentage scores on this quiz serve as the outcome of interest.
#
# However, it would be apparent that the prior level of knowledge a student possess about hypothesis testing may serve as a potential confounding variable that you would want to control for. Thus, the Prior Knowledge a given student has about hypothesis testing is categorized into "High" and "Low". The data from this experiment are contained in the `Data Science Teaching Method.xlsx` file. With these data, your tasks are:
#
# **Question 1.** Briefly define the objective of this experiment
#
# The objective of this experiment is to compare the effectiveness of three different teaching methods—Direct Instruction, Inquiry-Based Learning, and Collaborative Learning—on undergraduate students’ understanding of hypothesis testing. The study aims to determine which method leads to higher quiz performance while accounting for differences in students’ prior knowledge.
# **Question 2.** Specify the outcome variable
# The outcome variable is the students’ quiz score percentage on a 50-question test that measures their understanding of hypothesis testing.
#
# **Question 3.** Specify the independent variable and blocking factor. What are some possible lurking variables?
# Independent Variable (Treatment): Teaching method (Direct Instruction, Inquiry-Based, Collaborative).
# Blocking Factor: Prior knowledge level (High vs. Low).
# Possible Lurking Variables: Student motivation, study habits, instructor style, prior exposure to statistics courses, or test anxiety. These could influence performance if not controlled for.
#
# **Question 4.** Briefly explain why a randomized block design would be appropriate here. Similarly, explain why a completely randomized design would not be appropriate.
#
# A randomized block design is appropriate because it controls for the effect of prior knowledge, which is expected to strongly influence quiz scores. By blocking on prior knowledge, the comparison between teaching methods is made within each knowledge group, reducing variability and isolating the treatment effect.
# A completely randomized design would not be appropriate because it ignores prior knowledge, allowing this confounding variable to create misleading differences between teaching methods.
#
# **Question 5.** State the null and alternative hypotheses for this experiment.
#
# Null Hypothesis (H₀): There is no difference in mean quiz scores among the three teaching methods after controlling for prior knowledge.
# Alternative Hypothesis (H₁): At least one teaching method results in a different mean quiz score compared to the others after controlling for prior knowledge.
#
# **PART 2 INSTRUCTIONS**: Now suppose a university is evaluating the effectiveness of four different online learning platforms (say A, B, C, and D) on student engagement for students taking an undergraduate data science course in an online synchronous format. One section of the course is offered Monday through Thursday in the Morning, Early Afternoon, Mid-Afternoon, and Evening sections. Student engagement is measured through the total number of logins to the online learning platform for a given course section over the course of the
# semester. Below is a table describing the study design and factors:
#
#
# | Section \ Day     | Monday | Tuesday | Wednesday | Thursday |
# |-------------------|--------|---------|-----------|----------|
# | **Morning**       | A      | B       | C         | D        |
# | **Early Afternoon** | B      | C       | D         | A        |
# | **Mid-Afternoon** | C      | D       | A         | B        |
# | **Evening**       | D      | A       | B         | C        |
#
#
# Here, our main interest is in comparing engagement across the online learning platforms, but we also want to control for Day of the Week as well as Time of Day, as these could potentially be confounding variables. The data for this experiment are contained in the `Online Learning and Engagement.xlsx` file. With these data, your tasks are:
#
# **Question 1.** Briefly define the objective of this experiment
#
# The objective of this experiment is to compare the effectiveness of four online learning platforms (A, B, C, and D) in promoting student engagement, while controlling for potential confounding effects of Day of the Week and Time of Day.
#
# **Question 2.** Specify the outcome variable
# The outcome variable is the total number of student logins to the online learning platform for a given course section over the semester.
#
# **Question 3.** Specify the independent variable and blocking factors. What are some other possible lurking variables?
#
# Independent Variable (Treatment):
# The Online Learning Platform (A, B, C, D)
# Blocking Factors:
# Day of the Week (Monday to Thursday)
# Time of Day (Morning, Early Afternoon, Mid-Afternoon, Evening)
# Possible Lurking Variables:
# Instructor teaching style
# Course difficulty/content variation across sections
# Internet reliability at different times
# Student demographics or motivation
#
#
# **Question 4.** Briefly explain why a Latin Square Design would be appropriate here. Similarly, explain why a completely randomized design or randomized block design would not be appropriate.
#
#  A Latin Square Design is appropriate because there are two known sources of variation (Day of the Week and Time of Day) that we want to control without inflating the number of observations. This design ensures that each platform appears exactly once in each row (Time of Day) and each column (Day), isolating the effect of the platform from the blocks.
# A Completely Randomized Design would not control for Day or Time effects, potentially confounding results.
# A Randomized Block Design controls for only one blocking factor, but we have two, making Latin Square the better choice.
#
# **Question 5.** State the null and alternative hypotheses for this experiment.
#
# Null Hypothesis (H₀):
# There is no difference in student engagement (mean logins) across the four platforms.
# Alternative Hypothesis (H₁):
# At least one platform leads to different student engagement compared to the others.

# %% [markdown]
# Question 6. Perform appropriate exploratory analysis, including summary statistics and data visualizations. Do the results of these analyses support the null or alternative hypothesis more strongly?

# %%
# Step 1: Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the Excel file
file_path = '/content/STAT-7220-Applied-Experimental-Design/Assignments/HW2/Data Science Teaching Method.xlsx'
df = pd.read_excel(file_path, sheet_name='Sheet1')

# Summary statistics
summary_stats = df.groupby(['Teaching_Method', 'Prior_Knowledge'])['Score'].describe()
print("Summary Statistics:\n", summary_stats)

# Boxplot - Score by Teaching Method
plt.figure(figsize=(8, 6))
sns.boxplot(x='Teaching_Method', y='Score', data=df)
plt.title('Quiz Scores by Teaching Method')
plt.ylabel('Score')
plt.xlabel('Teaching Method')
plt.xticks(rotation=15)
plt.tight_layout()
plt.show()

# Boxplot - Teaching Method and Prior Knowledge
plt.figure(figsize=(10, 6))
sns.boxplot(x='Teaching_Method', y='Score', hue='Prior_Knowledge', data=df)
plt.title('Quiz Scores by Teaching Method and Prior Knowledge')
plt.ylabel('Score')
plt.xlabel('Teaching Method')
plt.xticks(rotation=15)
plt.tight_layout()
plt.show()

#  Histogram + KDE - Score Distribution by Teaching Method
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Score', hue='Teaching_Method', kde=True, element='step')
plt.title('Distribution of Scores by Teaching Method')
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()
# Out:
# Summary Statistics:
#                                   count    mean       std    min      25%  \
# Teaching_Method Prior_Knowledge
# Collaborative   High              10.0  90.927  7.970758  76.62  88.3125
#                 Low               10.0  82.176  8.168793  69.97  74.9625
# Direct          High              10.0  76.998  6.125899  69.25  73.4600
#                 Low               10.0  73.659  6.623811  59.89  74.1525
# Inquiry         High              10.0  88.624  5.316835  79.77  85.1000
#                 Low               10.0  81.903  5.984395  72.05  77.8425
#
#                                     50%      75%     max
# Teaching_Method Prior_Knowledge
# Collaborative   High             91.165  91.8775  105.06
#                 Low              82.450  89.6625   91.86
# Direct          High             75.930  80.7775   88.61
#                 Low              75.730  76.7450   80.20
# Inquiry         High             88.390  92.3175   98.18
# ...

# %% [markdown]
# Question 7. Build a three-way ANOVA model. Test the assumption of normality using both a visual method and a testing method. Do the results of the normality test(s) support the assumption of normality?
#
# A two-way ANOVA showed that both Teaching Method and Prior Knowledge significantly affect quiz scores, while their interaction is not significant. The Q-Q plot showed residuals roughly followed a normal distribution, and the Shapiro-Wilk test returned a p-value greater than 0.05. Therefore, the normality assumption is reasonably satisfied for the ANOVA model.

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from statsmodels.formula.api import ols
from scipy.stats import shapiro

# Load the dataset
file_path = '/content/STAT-7220-Applied-Experimental-Design/Assignments/HW2/Data Science Teaching Method.xlsx'
df = pd.read_excel(file_path, sheet_name='Sheet1')

# Fit a two-way ANOVA model (with interaction)
model = ols('Score ~ C(Teaching_Method) * C(Prior_Knowledge)', data=df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print("=== Two-Way ANOVA Table ===")
print(anova_table)

# Extract residuals
residuals = model.resid

# Q-Q Plot (Visual Normality Check)
sm.qqplot(residuals, line='45', fit=True)
plt.title('Q-Q Plot of ANOVA Residuals')
plt.tight_layout()
plt.show()

# Shapiro-Wilk Test (Statistical Normality Test)
shapiro_test = shapiro(residuals)
print("\n=== Shapiro-Wilk Test for Normality ===")
print(f"Test Statistic: {shapiro_test.statistic:.4f}")
print(f"p-value: {shapiro_test.pvalue:.4f}")

# Interpretation Guide (for your written answer)
if shapiro_test.pvalue > 0.05:
    print("\n✅ The residuals appear to be normally distributed (p > 0.05).")
else:
    print("\n❌ The residuals do not appear to be normally distributed (p < 0.05).")
# Out:
# === Two-Way ANOVA Table ===
#                                             sum_sq    df          F    PR(>F)
# C(Teaching_Method)                     1508.792653   2.0  16.415063  0.000003
# C(Prior_Knowledge)                      589.756202   1.0  12.832625  0.000731
# C(Teaching_Method):C(Prior_Knowledge)    74.747613   2.0   0.813224  0.448782
# Residual                               2481.708550  54.0        NaN       NaN
# === Shapiro-Wilk Test for Normality ===
# Test Statistic: 0.9843
# p-value: 0.6344
#
# ✅ The residuals appear to be normally distributed (p > 0.05).

# %% [markdown]
# Question 8. Test the assumption of homogeneity of variance using both a visual method and a testing method. Do the results of the test(s) support the assumption of homogeneity of variance?
#
# Levene’s test for homogeneity of variance returned a p-value of 0.7387, which is greater than 0.05. This indicates that the assumption of equal variances is met across groups. Therefore, the ANOVA results can be considered valid with respect to this assumption.

# %% [markdown]
# Question 9. Report the F-statistic and its associated p-value for the treatment effect. Which of our two hypotheses is more strongly supported? Why?
#
#
# The F-statistic for Teaching Method is 16.42 with a p-value of 0.000003. Since the p-value is much smaller than 0.05, we reject the null hypothesis that all teaching methods have the same mean quiz score. This strongly supports the alternative hypothesis, indicating that at least one teaching method leads to a significantly different outcome.

# %% [markdown]
# Question 10. If the data more strongly support the alternative hypothesis, perform Tukey's HSD post-hoc test to determine which levels of the treatment effect are significantly different from each other. If the data more strongly support the null hypothesis, explain why a post-hoc test would not be appropriate.
#
# Tukey's post-hoc test revealed that Direct Instruction significantly differs from both Collaborative Learning and Inquiry-Based Learning in terms of mean quiz scores. However, the difference between Collaborative Learning and Inquiry-Based Learning was not statistically significant. This suggests that Direct Instruction is less effective, while the other two methods perform similarly.

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# Run Tukey HSD for Teaching Method
tukey = pairwise_tukeyhsd(endog=df['Score'],
                          groups=df['Teaching_Method'],
                          alpha=0.05)

# Print results
print(tukey)

# Optional: Plot the Tukey HSD results
tukey.plot_simultaneous()
plt.title('Tukey HSD: Teaching Method Comparison')
plt.xlabel('Mean Difference in Scores')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#     group1     group2 meandiff p-adj   lower    upper  reject
# -------------------------------------------------------------
# Collaborative  Direct  -11.223    0.0 -16.8766 -5.5694   True
# Collaborative Inquiry   -1.288 0.8478  -6.9416  4.3656  False
#        Direct Inquiry    9.935 0.0003   4.2814 15.5886   True
# -------------------------------------------------------------

# %% [markdown]
# Question 11. Write a brief, contextual conclusion summarizing the results of your analyses, including potential limitations of this experiment.
#
# The results of this experiment show that teaching method has a significant effect on students' understanding of hypothesis testing, with Collaborative Learning and Inquiry-Based Learning leading to higher quiz scores than Direct Instruction. Prior knowledge also had a significant effect, but there was no interaction between teaching method and prior knowledge. A limitation of this study is the relatively small sample size and lack of long-term assessment, which may affect how well the results generalize beyond this specific workshop setting.

# %% [markdown]
# ## **PART 2 **
# Question 6. Perform appropriate exploratory analysis, including summary statistics and data visualizations. Do the results of these analyses support the null or alternative hypothesis more strongly?
#
# Summary statistics and boxplots show that Platforms A and D had higher average engagement, while C had the lowest. These differences support the alternative hypothesis, suggesting that at least one platform leads to significantly different engagement.

# %%
# Step 1: Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the Excel file for PART 2
file_path = '/content/STAT-7220-Applied-Experimental-Design/Assignments/HW2/Online Learning and Engagement.xlsx'
df_part2 = pd.read_excel(file_path, sheet_name='Sheet1')

# Check column names
print("Column names in the new dataframe:", df_part2.columns)

# Summary statistics by Platform
print("=== Summary Statistics ===")
# Assuming the platform column is named 'Platform' in the new file
# If the column name is different, this line will need adjustment after checking the output above
print(df_part2.groupby('Platform')['Engagement'].describe())

# Boxplot: Engagement by Platform
plt.figure(figsize=(8, 6))
sns.boxplot(data=df_part2, x='Platform', y='Engagement')
plt.title('Engagement by Online Learning Platform')
plt.tight_layout()
plt.show()

# Line plot: Engagement across Days
plt.figure(figsize=(10, 6))
# Assuming 'Day' and 'Section' columns exist in the new file
sns.lineplot(data=df_part2, x='Day', y='Engagement', hue='Platform', marker='o')
plt.title('Engagement Trends Across Days')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Boxplot: Engagement by Section (Time of Day)
plt.figure(figsize=(10, 6))
sns.boxplot(data=df_part2, x='Section', y='Engagement', hue='Platform')
plt.title('Engagement by Section and Platform')
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()
# Out:
# Column names in the new dataframe: Index(['Day', 'Section', 'Platform', 'Engagement'], dtype='object')
# === Summary Statistics ===
#           count       mean        std      min        25%       50%       75%  \
# Platform
# A           4.0  1377.7675  16.339232  1357.65  1370.5725  1378.150  1385.345
# B           4.0  1331.2625  28.513652  1288.86  1327.7925  1343.140  1346.610
# C           4.0  1303.8225  21.022768  1277.89  1293.4225  1304.805  1315.205
# D           4.0  1369.8225  13.753119  1356.74  1361.7875  1366.935  1374.970
#
#               max
# Platform
# A         1397.12
# B         1349.91
# C         1327.79
# D         1388.68

# %% [markdown]
# Question 7. Build a three-way ANOVA model. Test the assumption of normality using both a visual method and a testing method. Do the results of the normality test(s) support the assumption of normality?
#
#   The Shapiro-Wilk test returned a p-value of 0.9138, indicating that the residuals are normally distributed.
# This supports the assumption of normality, meaning the ANOVA results are valid.

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from statsmodels.formula.api import ols # Import ols
from scipy.stats import shapiro

# Build ANOVA model: Engagement ~ C(Platform) + C(Day) + C(Section)
model = ols('Engagement ~ C(Platform) + C(Day) + C(Section)', data=df_part2).fit() # Use df_part2
anova_table = sm.stats.anova_lm(model, typ=2)
print("\n=== ANOVA Table ===")
print(anova_table)

# Normality check: Q-Q plot
residuals = model.resid
sm.qqplot(residuals, line='45', fit=True)
plt.title("Q-Q Plot of Residuals")
plt.tight_layout()
plt.show()

# Shapiro-Wilk test
shapiro_test = shapiro(residuals)
print("\n=== Shapiro-Wilk Test ===")
print(f"Statistic: {shapiro_test.statistic:.4f}")
print(f"p-value: {shapiro_test.pvalue:.4f}")
# Out:
# === ANOVA Table ===
#                    sum_sq   df            F        PR(>F)
# C(Platform)  2.163185e+06  3.0  1639.526583  1.229404e-12
# C(Day)       1.175124e+03  3.0     0.890653  4.823487e-01
# C(Section)   2.434522e+06  3.0  1845.179206  7.230832e-13
# Residual     3.958188e+03  9.0          NaN           NaN
# === Shapiro-Wilk Test ===
# Statistic: 0.9752
# p-value: 0.9138

# %% [markdown]
# Question 8. Test the assumption of homogeneity of variance using both a visual method and a testing method. Do the results of the test(s) support the assumption of homogeneity of variance?
#
# The Levene’s test p-value is 0.9082, which is much greater than 0.05.
# This means the variances across platforms are equal, so the assumption of homogeneity of variance is satisfied for the ANOVA.

# %%
# Levene's test for equal variances
groups = [g['Engagement'].values for _, g in df.groupby('Platform')]
levene_test = levene(*groups)
print("\n=== Levene's Test for Homogeneity of Variance ===")
print(f"Statistic: {levene_test.statistic:.4f}")
print(f"p-value: {levene_test.pvalue:.4f}")
# Out:
# === Levene's Test for Homogeneity of Variance ===
# Statistic: 0.1796
# p-value: 0.9082

# %% [markdown]
# Question 9. Report the F-statistic and its associated p-value for the treatment effect. Which of our two hypotheses is more strongly supported? Why?
#
# The F-statistic for the treatment effect (Platform) is 1639.53, with a p-value of 1.23 × 10⁻¹².
# Since the p-value is far below 0.05, we reject the null hypothesis and conclude that at least one platform leads to significantly different engagement.
# This strongly supports the alternative hypothesis.

# %%
# Already printed above in ANOVA table, but reprint
print("\n=== Platform Effect from ANOVA ===")
print(anova_table.loc['C(Platform)'])
# Out:
# === Platform Effect from ANOVA ===
# sum_sq    2.163185e+06
# df        3.000000e+00
# F         1.639527e+03
# PR(>F)    1.229404e-12
# Name: C(Platform), dtype: float64

# %% [markdown]
# Question 10. If the data more strongly support the alternative hypothesis, perform Tukey's HSD post-hoc test to determine which levels of the treatment effect are significantly different from each other. If the data more strongly support the null hypothesis, explain why a post-hoc test would not be appropriate.
#
# Tukey’s HSD test showed that Platform A had significantly higher engagement than Platforms B and C, and Platform D had significantly higher engagement than Platform C.
# There were no significant differences between A and D, or between B and D.
# This suggests that Platforms A and D are the top performers, while Platform C underperforms.

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# Run Tukey HSD for Teaching Method
tukey = pairwise_tukeyhsd(endog=df_part2['Engagement'], # Use df_part2 and 'Engagement'
                          groups=df_part2['Platform'], # Use df_part2 and 'Platform'
                          alpha=0.05)

# Print results
print("\n=== Tukey HSD Results ===")
print(tukey)

# Optional: Plot the Tukey HSD results
tukey.plot_simultaneous()
plt.title('Tukey HSD: Platform Comparison') # Update title
plt.xlabel('Mean Difference in Engagement') # Update label
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# === Tukey HSD Results ===
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj    lower    upper   reject
# -------------------------------------------------------
#      A      B  -46.505 0.0347  -89.9249  -3.0851   True
#      A      C  -73.945 0.0014 -117.3649 -30.5251   True
#      A      D   -7.945 0.9466  -51.3649  35.4749  False
#      B      C   -27.44 0.2879  -70.8599  15.9799  False
#      B      D    38.56 0.0881   -4.8599  81.9799  False
#      C      D     66.0 0.0034   22.5801 109.4199   True
# -------------------------------------------------------

# %% [markdown]
# Question 11-
